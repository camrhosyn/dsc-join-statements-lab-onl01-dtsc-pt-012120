# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of `JOIN` statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# * Write SQL queries that make use of various types of joins
# * Compare and contrast the various types of joins
# * Discuss how primary and foreign keys are used in SQL
# * Decide and perform whichever type of join is best for retrieving desired data

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather than just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins** using shared columns from the two tables.
#
# In this lab, you'll use the same customer relationship management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database `'data.sqlite'`.

# %%
# Your code here
import sqlite3
import pandas as pd

conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston
#
# Hint: join the employees and offices tables.

# %%
# Your code here
cur.execute("""SELECT * 
               FROM employees
               JOIN offices
               ON employees.officeCode = offices.officeCode
               WHERE city = 'Boston'
               ;""")

# Take results and create DataFrame
df = pd.DataFrame(cur.fetchall()) 
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1188   Firrelli     Julie     x2173
# 1            1216  Patterson     Steve     x4334
#
#                              email  officeCode  reportsTo   jobTitle  \
# 0   jfirrelli@classicmodelcars.com           2       1143  Sales Rep
# 1  spatterson@classicmodelcars.com           2       1143  Sales Rep
#
#    officeCode    city            phone      addressLine1 addressLine2 state  \
# 0           2  Boston  +1 215 837 0825  1550 Court Place    Suite 102    MA
# 1           2  Boston  +1 215 837 0825  1550 Court Place    Suite 102    MA
#
#   country postalCode territory
# 0     USA      02107        NA
# 1     USA      02107        NA

# %% [markdown]
# ## Are there any offices that have zero employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
# Your code here
cur.execute("""SELECT offices.officeCode, sum(employeeNumber) AS num_emp
               FROM offices
               JOIN employees
               USING(officeCode)
               GROUP BY officeCode
               ;""")

# Take results and create DataFrame
df = pd.DataFrame(cur.fetchall()) 
df.columns = [i[0] for i in cur.description]
df.describe()
# Out:
#        officeCode      num_emp
# count    7.000000     7.000000
# mean     4.000000  4387.714286
# std      2.160247  1999.778714
# min      1.000000  2404.000000
# 25%      2.500000  2807.000000
# 50%      4.000000  3246.000000
# 75%      5.500000  6269.000000
# max      7.000000  6912.000000

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary
# Example: Display the htmlDescription and employee's first and last name for each product that each employee has sold

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of every individual product that each employee has sold

# %%
# Your code here
cur.execute("""SELECT employeeNumber, productName FROM employees
               JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
               JOIN orders ON customers.customerNumber = orders.customerNumber
               JOIN orderdetails ON orders.orderNumber = orderdetails.orderNumber
               JOIN products ON orderdetails.productCode = products.productCode
               ;""")

# Take results and create DataFrame
df1 = pd.DataFrame(cur.fetchall()) 
df1.columns = [i[0] for i in cur.description]
products_dict = {}
employees_list = df1['employeeNumber'].unique()
for number in employees_list:
    cur.execute("""SELECT employeeNumber, productName FROM employees
               JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
               JOIN orders ON customers.customerNumber = orders.customerNumber
               JOIN orderdetails ON orders.orderNumber = orderdetails.orderNumber
               JOIN products ON orderdetails.productCode = products.productCode
               WHERE employeeNumber IS {}
               ;""".format(number))
    df2 = pd.DataFrame(cur.fetchall()) 
    df2.columns = [i[0] for i in cur.description]
    print(df2['productName'].unique())
# Out:
# ['1958 Setra Bus' '1940 Ford Pickup Truck' '1939 Cadillac Limousine'
#  '1996 Peterbilt 379 Stake Bed with Outrigger' '1968 Ford Mustang'
#  '1968 Dodge Charger' '1970 Plymouth Hemi Cuda' '1969 Dodge Charger'
#  '1948 Porsche 356-A Roadster' '1969 Dodge Super Bee'
#  '1976 Ford Gran Torino' '1957 Vespa GS150' '1957 Corvette Convertible'
#  '1982 Ducati 900 Monster' '1982 Lamborghini Diablo'
#  '1971 Alpine Renault 1600s' '1956 Porsche 356A Coupe'
#  '1961 Chevrolet Impala' '1982 Ducati 996 R' '1974 Ducati 350 Mk3 Desmo'
#  '2002 Yamaha YZR M1' '2001 Ferrari Enzo' '1969 Corvair Monza'
#  '1969 Ford Falcon' '1903 Ford Model A' 'Collectable Wooden Train'
#  '1970 Triumph Spitfire' '1904 Buick Runabout' '18th century schooner'
#  '1912 Ford Model T Delivery Wagon'
#  "1950's Chicago Surface Lines Streetcar" '1962 City of Detroit Streetcar'
#  'The Schooner Bluenose' 'The Mayflower' 'The Titanic' 'The Queen Mary'
#  'Pont Yacht' '1937 Lincoln Berline'
# ...

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You practiced using join statements and leveraged your foreign keys knowledge!
